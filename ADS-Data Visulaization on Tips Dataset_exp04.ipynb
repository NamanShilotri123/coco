# %% [markdown]
# **Data Visulaization on Tips Dataset**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
tips=sns.load_dataset('tips')
df=pd.DataFrame(tips)
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.tip.describe()
# Out:
# count    244.000000
# mean       2.998279
# std        1.383638
# min        1.000000
# 25%        2.000000
# 50%        2.900000
# 75%        3.562500
# max       10.000000
# Name: tip, dtype: float64

# %%
bill=df.total_bill
print("Maximum Bill = ",np.max(bill))
print("Minimum Bill = ",np.min(bill))
print("Standard Deviation = ",np.std(bill))
print("Median = ",np.median(bill))
print("Mean = ",np.mean(bill))
# Out:
# Maximum Bill =  50.81
# Minimum Bill =  3.07
# Standard Deviation =  8.884150577771132
# Median =  17.795
# Mean =  19.78594262295082

# %%
bill=df.total_bill
print("Maximum Bill = ",np.max(bill))
print("Minimum Bill = ",np.min(bill))
print("Standard Deviation = ",np.std(bill))
print("Median = ",np.median(bill))
print("Mean = ",np.mean(bill))
# Out:
# Maximum Bill =  50.81
# Minimum Bill =  3.07
# Standard Deviation =  8.884150577771132
# Median =  17.795
# Mean =  19.78594262295082

# %%
sns.countplot(x='sex', data=tips,palette='dark')
sns.despine() # no top and right axis
print(tips.sex.value_counts())
# Out:
# <ipython-input-9-2f5023bd094a>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex', data=tips,palette='dark')
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
# More no. of Men have visited than female customer

# %%
sns.countplot(x='sex', data=tips, hue='smoker', palette='hls')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
# among customers more no. NON smoker paid tips than Smoker

# %%
plt.figure(figsize=(8,6))
plt.title("Tips per Day of Week")
sns.countplot(x=tips['day'],color='orange')
# Out:
# <Axes: title={'center': 'Tips per Day of Week'}, xlabel='day', ylabel='count'>

# %%
# More Tips are paid on Weekends(sat and Sun)

# %%
sns.catplot(x='day', data=tips, hue='sex', palette='Oranges', kind='count')

# %%
# More no. of tips of men paid on weekend and female paid tips more on weekdays

# %%
sns.distplot(df['tip'],color='green')
# Out:
# <ipython-input-17-659aa9ea21a5>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['tip'],color='green')
# <Axes: xlabel='tip', ylabel='Density'>

# %%
 #The distribution is skewed and more no. of Tips range is paid between 2 to 4 Dollars

# %%
g=sns.distplot(tips.tip,kde=False,color='red')
g.set_title('Tip Amount Histogram')
# Out:
# <ipython-input-19-92330d10d1ac>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   g=sns.distplot(tips.tip,kde=False,color='red')
# Text(0.5, 1.0, 'Tip Amount Histogram')

# %%
 #The distribution is skewed and more no. of Tips range is paid between 2 to 4 Dollars

# %%
plt.figure(figsize=(20,5))
sns.boxplot(x=bill, color='purple')
# Out:
# <Axes: xlabel='total_bill'>

# %%
# Outliers whose total bill is in the range of 40 to 50 Dollars. and Majority Of bill is between 15 dollar to 25 dollar

# %%
plt.figure(figsize=(20,5))
sns.boxplot(x=df.tip, palette='pastel')
# Out:
# <ipython-input-23-3354af10ae1c>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df.tip, palette='pastel')
# <Axes: xlabel='tip'>

# %%
# Majority of tips between 2 to 4 dollars and outliers lies between 6 to 10 dollars

# %%
sns.relplot(x='total_bill',y='tip',data=df,col='time',hue='smoker',size='size')

# %%
#There exists a liner relationship between total bill and the tip amount.
#More tips are observed during dinner time
#non smokers have higher amount of tips during lunch and dinner time.
#The size of group also have impact on the Tips more number of people in group have given larger tips.

# %%
plt.figure(figsize=(12,10))
sns.scatterplot(data=df,x='total_bill',y='tip',hue='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# It is observed that higher number of tips are given by male customers comapred to female customers.
# There is also a linear relationship between total bill and tip amount

# %%
sns.lmplot(x='total_bill',y='tip',data=df,col='time',hue='smoker')

# %%
# If bill amount is less, smokers give more tip than non smokers but they give less tips if the bill amount is high.
# So it is better to serve a non smoker if the bill amount is high.

# %%
sns.catplot(x='day',y='tip',data=df,kind='swarm',color='indigo')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# It is observed that more tips are given during weekends.
# Majority of tips are between 2 to 4 Dollars.
# Less tips are given on Friday.

# %%
sns.catplot(x='time',y='tip',data=df,height=6,kind='bar',palette='colorblind')
# Out:
# <ipython-input-33-b3e82b0a869e>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x='time',y='tip',data=df,height=6,kind='bar',palette='colorblind')

# %%
#more tips are given during dinner time

# %%
sns.catplot(x='day',y='tip',data=df,kind='violin',palette='pastel')
# Out:
# <ipython-input-35-51b5583065d5>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x='day',y='tip',data=df,kind='violin',palette='pastel')

# %%
# It is observed that more tips are given during weekends.
# Majority of tips are between 2 to 4 Dollars.
# Less tips are given on Friday.

# %%
sns.pairplot(df,hue='sex')

# %%
df_encoded = pd.get_dummies(df)


corr_matrix = df_encoded.corr()

ax = sns.heatmap(data=corr_matrix, annot=True, vmax=1, vmin=-1, center=0)

# %%
#Tip and tota bill have highest correlation

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder_df=LabelEncoder()
df['sex']=labelencoder_df.fit_transform(df['sex'])
df['smoker']=labelencoder_df.fit_transform(df['smoker'])
df['day']=labelencoder_df.fit_transform(df['day'])
df['time']=labelencoder_df.fit_transform(df['time'])
df.head()
# Out:
#    total_bill   tip  sex  smoker  day  time  size
# 0       16.99  1.01    0       0    2     0     2
# 1       10.34  1.66    1       0    2     0     3
# 2       21.01  3.50    1       0    2     0     3
# 3       23.68  3.31    1       0    2     0     2
# 4       24.59  3.61    0       0    2     0     4

# %%
corr_matrix=df.corr()
ax=sns.heatmap(data=corr_matrix,annot=True,vmax=1,vmin=-1,center=0)

# %%
#The highest co-relation exist between tip and the total bill. The least co-relation exist between day and smoker.

# %%
#Conclusion :- Data visualization is done on the tips dataset of Seaborn using plots for different types of variables and inferences are made about the relationship between total bill, tip, day, time, gender, smoker or non-smoker etc.
